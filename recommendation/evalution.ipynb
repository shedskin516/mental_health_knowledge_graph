# %%
import math
import pandas as pd

def get_DCG(groundtruth, pred_rank_list, k):
    dcg = 0
    groundtruth = list(map(lambda x: x.lower(), groundtruth))
    pred_rank_list = list(map(lambda x: x.lower(), pred_rank_list))

    for index, pred in enumerate(pred_rank_list):
        if index >= k:
            break
        if pred in groundtruth:
            dcg += (1) / math.log(index + 1 + 1, 2)

    idcg = 0
    num_item = int(min(k, len(groundtruth)))
    for i in range(num_item):
        idcg += (1) / math.log(i + 1 + 1, 2)
    ndcg = dcg / idcg

    return ndcg 


def get_recall(groundtruth, pred_rank_list, k):
    recall = 0
    groundtruth = list(map(lambda x: x.lower(), groundtruth))
    pred_rank_list = list(map(lambda x: x.lower(), pred_rank_list))

    for index, pred in enumerate(pred_rank_list):
        if index >= k:
            break
        if pred in groundtruth:
            recall += 1
    
    num_item = min(k, len(groundtruth))
    recall = float(recall) / num_item

    return recall


def evaluationWithK(gt, pred, k):
    recall = get_recall(gt, pred, k)
    dcg = get_DCG(gt, pred, k)

    print("recall@" + str(k) + ": " + str(recall), end=" ")
    print("dcg@" + str(k) + ": " + str(dcg), end=" ")
    return recall, dcg


def evaluation(gt, pred):
    recall3, dcg3 = evaluationWithK(gt, pred, 3)
    recall5, dcg5 = evaluationWithK(gt, pred, 5)
    recall10, dcg10 = evaluationWithK(gt, pred, 10)
    print()
    return recall3, dcg3, recall5, dcg5, recall10, dcg10

# %%
import pandas as pd
df = pd.read_csv('test.csv')
print(df.head())
# Out:
#                                          description  \
# 0  Recently I could hardly fall asleep. Every tim...
# 1  I was always a good tempered person. But since...
# 2  I think I am over sensitive because my parents...
# 3  I had a huge workload this quarter, and I have...
# 4  I hate to go to school, and I hate to do what ...
#
#                                                label  \
# 0                          anxiety,depression,stress
# 1  impulse control disorders,anger management,str...
# 2                         ADHD,child,family conflict
# 3  school issues,anxiety,depression,self esteem,s...
# 4  school issues,impulse control disorders,anger ...
#
#                                                 pred
# 0  anxiety,stress,grief,parenting,school issues,i...
# 1  anxiety,stress,grief,parenting,school issues,i...
# 2  anxiety,stress,grief,parenting,school issues,i...
# 3  anxiety,stress,grief,parenting,school issues,i...
# 4  anxiety,stress,grief,parenting,school issues,i...

# %%
r3, d3, r5, d5, r10, d10 = 0, 0, 0, 0, 0, 0

length = len(df.index)
print(length)

for index, row in df.iterrows():
    gt = row['label'].split(',')
    # gt = list(map(lambda x: x[1:-1], gt))
    print(gt)
    pred = row['pred'].split(',')
    # pred = list(map(lambda x: x[1:-1], pred))
    print(pred)
    recall3, dcg3, recall5, dcg5, recall10, dcg10 = evaluation(gt, pred)
    r3 += recall3
    d3 += dcg3
    r5 += recall5
    d5 += dcg5
    r10 += recall10
    d10 += dcg10
    print()
    
print("recall@3= " + str(r3/length))
print("dcg@3= " + str(d3/length))
print("recall@5= " + str(r5/length))
print("dcg@5= " + str(d5/length))
print("recall@10= " + str(r10/length))
print("dcg@10= " + str(d10/length))
# Out:
# 19
# ['anxiety', 'depression', 'stress']
# ['anxiety', 'stress', 'grief', 'parenting', 'school issues', 'impulse control disorders', 'emotional disturbance', 'anger management', 'depression', 'ADHD']
# recall@3: 0.6666666666666666 dcg@3: 0.7653606369886218 recall@5: 0.6666666666666666 dcg@5: 0.7653606369886218 recall@10: 1.0 dcg@10: 0.9066276098484508
#
# ['impulse control disorders', 'anger management', 'stress', 'relationship issues', 'life transitions']
# ['anxiety', 'stress', 'grief', 'parenting', 'school issues', 'impulse control disorders', 'emotional disturbance', 'anger management', 'depression', 'ADHD']
# recall@3: 0.3333333333333333 dcg@3: 0.2960819109658653 recall@5: 0.2 dcg@5: 0.21398626473452756 recall@10: 0.6 dcg@10: 0.44179069980128555
#
# ['ADHD', 'child', 'family conflict']
# ['anxiety', 'stress', 'grief', 'parenting', 'school issues', 'impulse control disorders', 'emotional disturbance', 'anger management', 'depression', 'ADHD']
# recall@3: 0.0 dcg@3: 0.0 recall@5: 0.0 dcg@5: 0.0 recall@10: 0.3333333333333333 dcg@10: 0.13565197343244778
#
# ['school issues', 'anxiety', 'depression', 'self esteem', 'stress']
# ['anxiety', 'stress', 'grief', 'parenting', 'school issues', 'impulse control disorders', 'emotional disturbance', 'anger management', 'depression', 'ADHD']
# recall@3: 0.6666666666666666 dcg@3: 0.7653606369886218 recall@5: 0.6 dcg@5: 0.6843515475204855 recall@10: 0.8 dcg@10: 0.7864489426433972
#
# ['school issues', 'impulse control disorders', 'anger management', 'child']
# ['anxiety', 'stress', 'grief', 'parenting', 'school issues', 'impulse control disorders', 'emotional disturbance', 'anger management', 'depression', 'ADHD']
# recall@3: 0.0 dcg@3: 0.0 recall@5: 0.25 dcg@5: 0.15101961822780527 recall@10: 0.75 dcg@10: 0.41322699210894587
#
# ['depression', 'spirituality']
# ['anxiety', 'stress', 'grief', 'parenting', 'school issues', 'impulse control disorders', 'emotional disturbance', 'anger management', 'depression', 'ADHD']
# recall@3: 0.0 dcg@3: 0.0 recall@5: 0.0 dcg@5: 0.0 recall@10: 0.5 dcg@10: 0.18457569677956817
#
# ['anxiety', 'depression', 'self esteem']
# ['anxiety', 'stress', 'grief', 'parenting', 'school issues', 'impulse control disorders', 'emotional disturbance', 'anger management', 'depression', 'ADHD']
# recall@3: 0.3333333333333333 dcg@3: 0.46927872602275655 recall@5: 0.3333333333333333 dcg@5: 0.46927872602275655 recall@10: 0.6666666666666666 dcg@10: 0.6105456988825856
#
# ['depression', 'life transitions']
# ['anxiety', 'stress', 'grief', 'parenting', 'school issues', 'impulse control disorders', 'emotional disturbance', 'anger management', 'depression', 'ADHD']
# recall@3: 0.0 dcg@3: 0.0 recall@5: 0.0 dcg@5: 0.0 recall@10: 0.5 dcg@10: 0.18457569677956817
#
# ["'trauma and PTSD'"]
# ['anxiety', 'stress', 'grief', 'parenting', 'school issues', 'impulse control disorders', 'emotional disturbance', 'anger management', 'depression', 'ADHD']
# recall@3: 0.0 dcg@3: 0.0 recall@5: 0.0 dcg@5: 0.0 recall@10: 0.0 dcg@10: 0.0
#
# ['stress', 'coping skills']
# ['anxiety', 'stress', 'grief', 'parenting', 'school issues', 'impulse control disorders', 'emotional disturbance', 'anger management', 'depression', 'ADHD']
# recall@3: 0.5 dcg@3: 0.38685280723454163 recall@5: 0.5 dcg@5: 0.38685280723454163 recall@10: 0.5 dcg@10: 0.38685280723454163
#
# ['suicidal ideation', 'grief', 'stress', 'trauma and PTSD']
# ['anxiety', 'stress', 'grief', 'parenting', 'school issues', 'impulse control disorders', 'emotional disturbance', 'anger management', 'depression', 'ADHD']
# recall@3: 0.6666666666666666 dcg@3: 0.5307212739772434 recall@5: 0.5 dcg@5: 0.44149241373678083 recall@10: 0.5 dcg@10: 0.44149241373678083
#
# ['trauma and PTSD', 'stress']
# ['anxiety', 'stress', 'grief', 'parenting', 'school issues', 'impulse control disorders', 'emotional disturbance', 'anger management', 'depression', 'ADHD']
# recall@3: 0.5 dcg@3: 0.38685280723454163 recall@5: 0.5 dcg@5: 0.38685280723454163 recall@10: 0.5 dcg@10: 0.38685280723454163
#
# ['depression', 'spirituality']
# ['anxiety', 'stress', 'grief', 'parenting', 'school issues', 'impulse control disorders', 'emotional disturbance', 'anger management', 'depression', 'ADHD']
# recall@3: 0.0 dcg@3: 0.0 recall@5: 0.0 dcg@5: 0.0 recall@10: 0.5 dcg@10: 0.18457569677956817
#
# ['anxiety', 'stress', 'self esteem']
# ['anxiety', 'stress', 'grief', 'parenting', 'school issues', 'impulse control disorders', 'emotional disturbance', 'anger management', 'depression', 'ADHD']
# recall@3: 0.6666666666666666 dcg@3: 0.7653606369886218 recall@5: 0.6666666666666666 dcg@5: 0.7653606369886218 recall@10: 0.6666666666666666 dcg@10: 0.7653606369886218
#
# ['stress', 'anxiety']
# ['anxiety', 'stress', 'grief', 'parenting', 'school issues', 'impulse control disorders', 'emotional disturbance', 'anger management', 'depression', 'ADHD']
# recall@3: 1.0 dcg@3: 1.0 recall@5: 1.0 dcg@5: 1.0 recall@10: 1.0 dcg@10: 1.0
#
# ['stress', 'anxiety', 'school issues', 'depression']
# ['anxiety', 'stress', 'grief', 'parenting', 'school issues', 'impulse control disorders', 'emotional disturbance', 'anger management', 'depression', 'ADHD']
# recall@3: 0.6666666666666666 dcg@3: 0.7653606369886218 recall@5: 0.75 dcg@5: 0.787702056960637 recall@10: 1.0 dcg@10: 0.9052181617170642
#
# ['self esteem', 'coping skills']
# ['anxiety', 'stress', 'grief', 'parenting', 'school issues', 'impulse control disorders', 'emotional disturbance', 'anger management', 'depression', 'ADHD']
# recall@3: 0.0 dcg@3: 0.0 recall@5: 0.0 dcg@5: 0.0 recall@10: 0.0 dcg@10: 0.0
#
# ['relationship issues', 'family conflict', 'addiction']
# ['anxiety', 'stress', 'grief', 'parenting', 'school issues', 'impulse control disorders', 'emotional disturbance', 'anger management', 'depression', 'ADHD']
# recall@3: 0.0 dcg@3: 0.0 recall@5: 0.0 dcg@5: 0.0 recall@10: 0.0 dcg@10: 0.0
#
# ['self esteem', 'stress']
# ['anxiety', 'stress', 'grief', 'parenting', 'school issues', 'impulse control disorders', 'emotional disturbance', 'anger management', 'depression', 'ADHD']
# recall@3: 0.5 dcg@3: 0.38685280723454163 recall@5: 0.5 dcg@5: 0.38685280723454163 recall@10: 0.5 dcg@10: 0.38685280723454163
#
# recall@3= 0.34210526315789475
# dcg@3= 0.34305699371705145
# recall@5= 0.34035087719298246
# dcg@5= 0.3389005433096769
# recall@10= 0.5429824561403509
# dcg@10= 0.42740256006325844
