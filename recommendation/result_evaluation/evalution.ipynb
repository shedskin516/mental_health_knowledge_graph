# %%
import math
import pandas as pd

def get_DCG(groundtruth, pred_rank_list, k):
    dcg = 0
    groundtruth = list(map(lambda x: x.lower(), groundtruth))
    pred_rank_list = list(map(lambda x: x.lower(), pred_rank_list))

    for index, pred in enumerate(pred_rank_list):
        if index >= k:
            break
        if pred in groundtruth:
            dcg += (1) / math.log(index + 1 + 1, 2)

    idcg = 0
    num_item = int(min(k, len(groundtruth)))
    for i in range(num_item):
        idcg += (1) / math.log(i + 1 + 1, 2)
    ndcg = dcg / idcg

    return ndcg 


def get_recall(groundtruth, pred_rank_list, k):
    recall = 0
    groundtruth = list(map(lambda x: x.lower(), groundtruth))
    pred_rank_list = list(map(lambda x: x.lower(), pred_rank_list))

    for index, pred in enumerate(pred_rank_list):
        if index >= k:
            break
        if pred in groundtruth:
            recall += 1
    
    num_item = min(k, len(groundtruth))
    recall = float(recall) / num_item

    return recall


def evaluationWithK(gt, pred, k):
    recall = get_recall(gt, pred, k)
    dcg = get_DCG(gt, pred, k)

    print("recall@" + str(k) + ": " + str(recall), end=" ")
    print("dcg@" + str(k) + ": " + str(dcg), end=" ")
    return recall, dcg


def evaluation(gt, pred):
    recall3, dcg3 = evaluationWithK(gt, pred, 3)
    recall5, dcg5 = evaluationWithK(gt, pred, 5)
    recall10, dcg10 = evaluationWithK(gt, pred, 10)
    print()
    return recall3, dcg3, recall5, dcg5, recall10, dcg10

# %%
import pandas as pd
df = pd.read_csv('test.csv')
print(df.head())
# Out:
#                                          description  \
# 0  Recently I could hardly fall asleep. Every tim...
# 1  I was always a good tempered person. But since...
# 2  I think I am over sensitive because my parents...
# 3  I had a huge workload this quarter, and I have...
# 4  I hate to go to school, and I hate to do what ...
#
#                                                label  \
# 0                          anxiety,depression,stress
# 1  impulse control disorders,anger management,str...
# 2                         ADHD,child,family conflict
# 3  school issues,anxiety,depression,self esteem,s...
# 4  school issues,impulse control disorders,anger ...
#
#                                                 pred
# 0  infidelity,life transitions,emotional disturba...
# 1  self esteem,child,coping skills,spirituality,a...
# 2  family conflict,stress,behavioral issues,copin...
# 3  spirituality,adhd,grief,life coaching,anxiety,...
# 4  family conflict,adhd,child,anxiety,life coachi...

# %%
r3, d3, r5, d5, r10, d10 = 0, 0, 0, 0, 0, 0

length = len(df.index)
print(length)

for index, row in df.iterrows():
    gt = row['label'].split(',')
    # gt = list(map(lambda x: x[1:-1], gt))
    print(gt)
    pred = row['pred'].split(',')
    # pred = list(map(lambda x: x[1:-1], pred))
    print(pred)
    recall3, dcg3, recall5, dcg5, recall10, dcg10 = evaluation(gt, pred)
    r3 += recall3
    d3 += dcg3
    r5 += recall5
    d5 += dcg5
    r10 += recall10
    d10 += dcg10
    print()
    
print("recall@3= " + str(r3/length))
print("dcg@3= " + str(d3/length))
print("recall@5= " + str(r5/length))
print("dcg@5= " + str(d5/length))
print("recall@10= " + str(r10/length))
print("dcg@10= " + str(d10/length))
# Out:
# 19
# ['anxiety', 'depression', 'stress']
# ['infidelity', 'life transitions', 'emotional disturbance', 'impulse control disorders', 'coping skills', 'school issues', 'trauma and ptsd', 'peer relationships', 'life coaching', 'codependency', 'anxiety', 'suicidal ideation']
# recall@3: 0.0 dcg@3: 0.0 recall@5: 0.0 dcg@5: 0.0 recall@10: 0.0 dcg@10: 0.0
#
# ['impulse control disorders', 'anger management', 'stress', 'relationship issues', 'life transitions']
# ['self esteem', 'child', 'coping skills', 'spirituality', 'anger management', 'addiction', 'marital and premarital', 'emotional disturbance', 'grief', 'relationship issues', 'sexual abuse', 'codependency']
# recall@3: 0.0 dcg@3: 0.0 recall@5: 0.2 dcg@5: 0.1312050775123418 recall@10: 0.4 dcg@10: 0.22924436334369885
#
# ['ADHD', 'child', 'family conflict']
# ['family conflict', 'stress', 'behavioral issues', 'coping skills', 'life coaching', 'parenting', 'marital and premarital', 'anger management', 'divorce', 'sexual abuse', 'depression', 'grief']
# recall@3: 0.3333333333333333 dcg@3: 0.46927872602275655 recall@5: 0.3333333333333333 dcg@5: 0.46927872602275655 recall@10: 0.3333333333333333 dcg@10: 0.46927872602275655
#
# ['school issues', 'anxiety', 'depression', 'self esteem', 'stress']
# ['spirituality', 'adhd', 'grief', 'life coaching', 'anxiety', 'bipolar disorder', 'depression', 'coping skills', 'parenting', 'substance use', 'self esteem', 'divorce']
# recall@3: 0.0 dcg@3: 0.0 recall@5: 0.2 dcg@5: 0.1312050775123418 recall@10: 0.4 dcg@10: 0.24425847927021385
#
# ['school issues', 'impulse control disorders', 'anger management', 'child']
# ['family conflict', 'adhd', 'child', 'anxiety', 'life coaching', 'school issues', 'substance use', 'emotional disturbance', 'codependency', 'grief', 'peer relationships', 'behavioral issues']
# recall@3: 0.3333333333333333 dcg@3: 0.23463936301137828 recall@5: 0.25 dcg@5: 0.19519002499605087 recall@10: 0.5 dcg@10: 0.3342462045068265
#
# ['depression', 'spirituality']
# ['suicidal ideation', 'depression', 'child', 'divorce', 'spirituality', 'life coaching', 'behavioral issues', 'adhd', 'bipolar disorder', 'trauma and ptsd', 'emotional disturbance', 'anxiety']
# recall@3: 0.5 dcg@3: 0.38685280723454163 recall@5: 1.0 dcg@5: 0.6240505200038378 recall@10: 1.0 dcg@10: 0.6240505200038378
#
# ['anxiety', 'depression', 'self esteem']
# ['suicidal ideation', 'life coaching', 'grief', 'adhd', 'depression', 'coping skills', 'anger management', 'divorce', "women's issues", 'self esteem', 'stress', 'emotional disturbance']
# recall@3: 0.0 dcg@3: 0.0 recall@5: 0.3333333333333333 dcg@5: 0.1815417925373527 recall@10: 0.6666666666666666 dcg@10: 0.31719376596980053
#
# ['depression', 'life transitions']
# ['suicidal ideation', 'grief', 'adhd', 'depression', 'parenting', 'anger management', 'life coaching', 'marital and premarital', 'codependency', "women's issues", 'child', 'emotional disturbance']
# recall@3: 0.0 dcg@3: 0.0 recall@5: 0.5 dcg@5: 0.2640681225725909 recall@10: 0.5 dcg@10: 0.2640681225725909
#
# ["'trauma and PTSD'"]
# ['grief', 'addiction', 'anxiety', 'trauma and ptsd', 'spirituality', 'stress', 'anger management', 'suicidal ideation', 'family conflict', 'substance use', 'divorce', 'codependency']
# recall@3: 0.0 dcg@3: 0.0 recall@5: 0.0 dcg@5: 0.0 recall@10: 0.0 dcg@10: 0.0
#
# ['stress', 'coping skills']
# ['suicidal ideation', 'depression', 'marital and premarital', 'anxiety', 'bipolar disorder', 'adhd', 'substance use', 'emotional disturbance', 'grief', "women's issues", 'addiction', 'codependency']
# recall@3: 0.0 dcg@3: 0.0 recall@5: 0.0 dcg@5: 0.0 recall@10: 0.0 dcg@10: 0.0
#
# ['suicidal ideation', 'grief', 'stress', 'trauma and PTSD']
# ['suicidal ideation', 'adhd', 'depression', 'emotional disturbance', "women's issues", 'sexual abuse', 'parenting', 'grief', 'life coaching', 'marital and premarital', 'spirituality', 'anxiety']
# recall@3: 0.3333333333333333 dcg@3: 0.46927872602275655 recall@5: 0.25 dcg@5: 0.39038004999210174 recall@10: 0.5 dcg@10: 0.5135312443624668
#
# ['trauma and PTSD', 'stress']
# ['anxiety', 'grief', 'divorce', 'trauma and ptsd', 'self esteem', 'anger management', 'stress', 'spirituality', 'depression', 'addiction', 'coping skills', 'impulse control disorders']
# recall@3: 0.0 dcg@3: 0.0 recall@5: 0.5 dcg@5: 0.2640681225725909 recall@10: 1.0 dcg@10: 0.468450520161077
#
# ['depression', 'spirituality']
# ['depression', 'suicidal ideation', 'spirituality', 'adhd', 'codependency', 'self esteem', 'parenting', 'child', 'emotional disturbance', 'anger management', 'grief', "women's issues"]
# recall@3: 1.0 dcg@3: 0.9197207891481877 recall@5: 1.0 dcg@5: 0.9197207891481877 recall@10: 1.0 dcg@10: 0.9197207891481877
#
# ['anxiety', 'stress', 'self esteem']
# ['infidelity', 'self esteem', 'grief', 'stress', 'life coaching', 'life transitions', 'anxiety', 'adhd', 'coping skills', 'divorce', 'addiction', 'depression']
# recall@3: 0.3333333333333333 dcg@3: 0.2960819109658653 recall@5: 0.6666666666666666 dcg@5: 0.49818925746641285 recall@10: 1.0 dcg@10: 0.6546154994739983
#
# ['stress', 'anxiety']
# ['life coaching', 'self esteem', 'spirituality', 'adhd', 'codependency', 'suicidal ideation', 'substance use', 'parenting', 'anxiety', 'bipolar disorder', 'marital and premarital', 'grief']
# recall@3: 0.0 dcg@3: 0.0 recall@5: 0.0 dcg@5: 0.0 recall@10: 0.5 dcg@10: 0.18457569677956817
#
# ['stress', 'anxiety', 'school issues', 'depression']
# ['depression', 'bipolar disorder', 'suicidal ideation', 'life coaching', 'anxiety', 'adhd', 'school issues', 'trauma and ptsd', 'marital and premarital', 'spirituality', 'stress', 'infidelity']
# recall@3: 0.3333333333333333 dcg@3: 0.46927872602275655 recall@5: 0.5 dcg@5: 0.541399668219907 recall@10: 0.75 dcg@10: 0.6715263515506076
#
# ['self esteem', 'coping skills']
# ['spirituality', 'suicidal ideation', 'grief', 'depression', 'substance use', 'codependency', 'anxiety', 'divorce', 'coping skills', 'life coaching', 'anger management', 'self esteem']
# recall@3: 0.0 dcg@3: 0.0 recall@5: 0.0 dcg@5: 0.0 recall@10: 0.5 dcg@10: 0.18457569677956817
#
# ['relationship issues', 'family conflict', 'addiction']
# ['family conflict', 'behavioral issues', 'suicidal ideation', 'grief', 'anxiety', 'parenting', 'depression', 'divorce', 'stress', 'addiction', 'anger management', 'self esteem']
# recall@3: 0.3333333333333333 dcg@3: 0.46927872602275655 recall@5: 0.3333333333333333 dcg@5: 0.46927872602275655 recall@10: 0.6666666666666666 dcg@10: 0.6049306994552044
#
# ['self esteem', 'stress']
# ['suicidal ideation', 'depression', 'life coaching', 'spirituality', 'family conflict', 'adhd', 'substance use', 'emotional disturbance', 'relationship issues', 'anxiety', 'divorce', 'grief']
# recall@3: 0.0 dcg@3: 0.0 recall@5: 0.0 dcg@5: 0.0 recall@10: 0.0 dcg@10: 0.0
#
# recall@3= 0.1842105263157895
# dcg@3= 0.19549525128689468
# recall@5= 0.3192982456140351
# dcg@5= 0.26734610287259103
# recall@10= 0.5114035087719299
# dcg@10= 0.3518035094421264
